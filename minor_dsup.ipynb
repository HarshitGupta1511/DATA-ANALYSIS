# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshitGupta1511/DATA-ANALYSIS/blob/main/minor_dsup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = ['apple', 'banana', 'orange', 'grape', 'kiwi','papaya','watermelon','dragonfruit','mango']

# %%
df = pd.DataFrame(data, columns=['Fruit'])

# %%
print(df)
# Out:
#          Fruit
# 0        apple
# 1       banana
# 2       orange
# 3        grape
# 4         kiwi
# 5       papaya
# 6   watermelon
# 7  dragonfruit
# 8        mango
